# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
from collections import defaultdict
from tqdm import tqdm

# %% [markdown]
# # 종목별 비슷한 회사 묶음

# %%
html = urlopen(None)
bsObject = BeautifulSoup(html, "html.parser") 

classification_of_business = defaultdict(list)

path = None
for ref in bsObject.select_one('table').select('a'):
    if ref.text == '기타':
        continue
    link = urlopen(path + ref.get('href'))
    link_page = BeautifulSoup(link, "html.parser")
    for name in link_page.select('table tbody .name'):
        text = name.text
        if text.find('*') != -1:
            text = text[:-2]
        classification_of_business['name'].append(text)
        classification_of_business['business_category'].append(ref.text)

classification_of_business = pd.DataFrame(dict(classification_of_business))

# %%
classification_of_business
# Out:
#          name business_category
# 0          루닛            건강관리기술
# 1       제이엘케이            건강관리기술
# 2          뷰노            건강관리기술
# 3     라이프시맨틱스            건강관리기술
# 4       비트컴퓨터            건강관리기술
# ...       ...               ...
# 2723   제일테크노스              건축제품
# 2724   금강공업우               건축제품
# 2725    덕신하우징              건축제품
# 2726      뉴보텍              건축제품
# 2727    금강공업               건축제품
#
# [2728 rows x 2 columns]

# %% [markdown]
# # 회사를 그룹별로 묶음

# %%
html = urlopen(None)
bsObject = BeautifulSoup(html, "html.parser") 

group_of_business = defaultdict(list)

path = None
for ref in bsObject.select_one('table').select('a'):
    link = urlopen(path + ref.get('href'))
    link_page = BeautifulSoup(link, "html.parser")
    for name in link_page.select('table tbody .name'):
        text = name.text
        if text.find('*') != -1:
            text = text[:-2]
        group_of_business['name'].append(text)
        group_of_business['group'].append(ref.text)

group_of_business = pd.DataFrame(dict(group_of_business))

# %%
group_of_business
# Out:
#           name group
# 0         에코프로  에코프로
# 1     에코프로에이치엔  에코프로
# 2       에코프로비엠  에코프로
# 3    포스코인터내셔널    포스코
# 4        포스코엠텍   포스코
# ..         ...   ...
# 338     웅진씽크빅     웅진
# 339    미래에셋증권   미래에셋
# 340   미래에셋벤처투자  미래에셋
# 341    미래에셋생명   미래에셋
# 342       아이톡시  미래에셋
#
# [343 rows x 2 columns]

# %% [markdown]
# # 회사 테마별로 묶음

# %%
theme_of_business = defaultdict(list)
for page in range(1, 8):
    html = urlopen(None + str(page))
    bsObject = BeautifulSoup(html, "html.parser") 

    path = None
    for ref in tqdm(bsObject.select_one('table').select('a')):
        link = urlopen(path + ref.get('href'))
        link_page = BeautifulSoup(link, "html.parser")
        for name in link_page.select('table tbody .name'):
            text = name.text
            if text.find('*') != -1:
                text = text[:-2]
            theme_of_business['name'].append(text)
            theme_of_business['theme'].append(ref.text)
theme_of_business = pd.DataFrame(dict(theme_of_business))

# %%
theme_of_business
# Out:
#          name  theme
# 0         금양      리튬
# 1      코스모화학      리튬
# 2       강원에너지     리튬
# 3     이브이첨단소재     리튬
# 4       리튬포어스     리튬
# ...       ...    ...
# 6974    범양건영   모듈러주택
# 6975    GS건설   모듈러주택
# 6976    덕신하우징  모듈러주택
# 6977    자연과환경  모듈러주택
# 6978    금강공업   모듈러주택
#
# [6979 rows x 2 columns]

# %%
folder = None
classification_of_business.to_csv(folder + 'classification_of_business.csv', index=False)
group_of_business.to_csv(folder + 'group_of_business.csv', index=False)
theme_of_business.to_csv(folder + 'theme_of_business.csv', index=False)

# %% [markdown]
# # 멀티 프로세싱, 멀티 쓰레딩

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
from collections import defaultdict
from tqdm import tqdm
from multiprocessing import Pool
from concurrent.futures import ThreadPoolExecutor
import time
import concurrent.futures
import requests
import os

def do_html_crawl(url: str, ref: str):
    theme_of_business = dict()
    link = requests.get(url)
    link_page = BeautifulSoup(link.text, "html.parser")
    for name in link_page.select('table tbody .name'):
        text = name.text
        if text.find('*') != -1:
            text = text[:-2]
        theme_of_business[text] = ref.text
    return theme_of_business

def do_process_crawl(urls: str):
    return do_thread_crawl(urls)

def do_thread_crawl(url: str):
    html = requests.get(url)
    bsObject = BeautifulSoup(html.text, "html.parser")
    refs = bsObject.select_one('table').select('a')
    thread_list = []
    with ThreadPoolExecutor(max_workers=8) as executor:
        for ref in refs:
            path = None
            url = naver + ref.get('href')
            thread_list.append(executor.submit(do_html_crawl, url, ref))
        results = []
        for execution in concurrent.futures.as_completed(thread_list):
            result = execution.result()
            results.append(result)
    return results

start_time = time.time()
urls = [None for page in range(1, 8)]
results = []
with Pool(processes=7) as pool:
    results.append(pool.map(do_process_crawl, urls))
print(results)
print(f"elapsed time = {time.time() - start_time}")
# Out:
# [[[{}, {'비에이치아이': '원자력발전소 해체', '우진 ': '원자력발전소 해체', '한전기술 ': '원자력발전소 해체', '우리기술': '원자력발전소 해체', '두산에너빌리티 ': '원자력발전소 해체', '에이비프로바이오': '원자력발전소 해체', '오르비텍': '원자력발전소 해체', '휴림로봇': '원자력발전소 해체', '한전KPS ': '원자력발전소 해체', '에스앤더블류': '원자력발전소 해체', '현대건설 ': '원자력발전소 해체', '비츠로테크': '원자력발전소 해체', '휴비스 ': '원자력발전소 해체', '한국테크놀로지': '원자력발전소 해체', '대창솔루션': '원자력발전소 해체'}, {}, {}, {'한미반도체 ': 'LED장비', '이오테크닉스': 'LED장비', '프로텍': 'LED장비', '주성엔지니어링': 'LED장비', '레이저쎌': 'LED장비', '코디': 'LED장비', '예스티': 'LED장비', '기가레인': 'LED장비', '티씨케이': 'LED장비', '미래컴퍼니': 'LED장비', '네온테크': 'LED장비', '탑엔지니어링': 'LED장비', '엘아이에스': 'LED장비', '티에스이': 'LED장비'}, {}, {}, {}, {}, {'알에프세미': 'MLCC(적층세라믹콘덴서)', '아모텍': 'MLCC(적층세라믹콘덴서)', '윈텍': 'MLCC(적층세라믹콘덴서)', '삼성전기 ': 'MLCC(적층세라믹콘덴서)', '삼화콘덴서 ': 'MLCC(적층세라믹콘덴서)', '네온테크': 'MLCC(적층세라믹콘덴서)', '아바텍': 'MLCC(적층세라믹콘덴서)', '대주전자재료': 'MLCC(적층세라믹콘덴서)', '코스모신소재 ': 'MLCC(적층세라믹콘덴서)'}, {}, {'알에프세미': '지능형로봇/인공지능(AI)', '제이엘케이': '지능형로봇/인공지능(AI)', '뷰노': '지능형로봇/인공지능(AI)', '딥노이드': '지능형로봇/인공지능(AI)', '라온피플': '지능형로봇/인공지능(AI)', '엠로': '지능형로봇/인공지능(AI)', '신테카바이오': '지능형로봇/인공지능(AI)', '마음AI': '지능형로봇/인공지능(AI)', '브레인즈컴퍼니': '지능형로봇/인공지능(AI)', '오브젠': '지능형로봇/인공지능(AI)', '큐렉소': '지능형로봇/인공지능(AI)', '루닛': '지능형로봇/인공지능(AI)', '솔트룩스': '지능형로봇/인공지능(AI)', '티로보틱스': '지능형로봇/인공지능(AI)', '셀바스AI': '지능형로봇/인공지능(AI)', '바이브컴퍼니': '지능형로봇/인공지능(AI)', '코난테크놀로지': '지능형로봇/인공지능(AI)', '싸이맥스': '지능형로봇/인공지능(AI)', '고영': '지능형로봇/인공지능(AI)', '우리기술': '지능형로봇/인공지능(AI)', '알체라': '지능형로봇/인공지능(AI)', '가온그룹': '지능형로봇/인공지능(AI)', '줌인터넷': '지능형로봇/인공지능(AI)', '한화에어로스페이스 ': '지능형로봇/인공지능(AI)', '모아데이타': '지능형로봇/인공지능(AI)', '휴림로봇': '지능형로봇/인공지능(AI)', '핀텔': '지능형로봇/인공지능(AI)', '위세아이텍': '지능형로봇/인공지능(AI)', '오픈베이스': '지능형로봇/인공지능(AI)', '비플라이소프트': '지능형로봇/인공지능(AI)', '네패스': '지능형로봇/인공지능(AI)', '유일로보틱스': '지능형로봇/인공지능(AI)', '로보로보': '지능형로봇/인공지능(AI)', '에이디칩스': '지능형로봇/인공지능(AI)', '네오펙트': '지능형로봇/인공지능(AI)', '러셀': '지능형로봇/인공지능(AI)', '유진로봇': '지능형로봇/인공지능(AI)', '에스티큐브': '지능형로봇/인공지능(AI)', '영우디에스피': '지능형로봇/인공지능(AI)', '데이타솔루션': '지능형로봇/인공지능(AI)', '이랜시스': '지능형로봇/인공지능(AI)', '스맥': '지능형로봇/인공지능(AI)', '에브리봇': '지능형로봇/인공지능(AI)', 'LG전자 ': '지능형로봇/인공지능(AI)', '링크제니시스': '지능형로봇/인공지능(AI)', '에스피시스템스': '지능형로봇/인공지능(AI)', '엑셈': '지능형로봇/인공지능(AI)', 'TPC': '지능형로봇/인공지능(AI)', '와이더플래닛': '지능형로봇/인공지능(AI)', '커머스마이너': '지능형로봇/인공지능(AI)', '미래컴퍼니': '지능형로봇/인공지능(AI)', '로보티즈': '지능형로봇/인공지능(AI)', '노블엠앤비': '지능형로봇/인공지능(AI)', '한국전자인증': '지능형로봇/인공지능(AI)', '씨유박스': '지능형로봇/인공지능(AI)', '트윔': '지능형로봇/인공지능(AI)', '레인보우로보틱스': '지능형로봇/인공지능(AI)', '로보스타': '지능형로봇/인공지능(AI)', '인포마크': '지능형로봇/인공지능(AI)', '퍼스텍 ': '지능형로봇/인공지능(AI)', '모비스': '지능형로봇/인공지능(AI)'}, {}, {'한미반도체 ': '전자파', '제너셈': '전자파', '프로텍': '전자파', '아모텍': '전자파', '레몬': '전자파', '동일기연': '전자파', '다산솔루에타': '전자파', '잉크테크': '전자파', '이큐셀': '전자파', '아이씨에이치': '전자파', '성우전자': '전자파', '켐트로닉스': '전자파', '상신전자': '전자파'}, {}, {}, {}, {}, {'비에이치아이': '셰일가스(Shale Gas)', '한국카본 ': '셰일가스(Shale Gas)', '두산에너빌리티 ': '셰일가스(Shale Gas)', '한국전력 ': '셰일가스(Shale Gas)', '한국가스공사 ': '셰일가스(Shale Gas)', '포스코인터내셔널 ': '셰일가스(Shale Gas)', 'E1 ': '셰일가스(Shale Gas)', 'SH에너지화학 ': '셰일가스(Shale Gas)', '우림피티에스': '셰일가스(Shale Gas)', 'SNT에너지 ': '셰일가스(Shale Gas)', '동성화인텍': '셰일가스(Shale Gas)', 'GS글로벌 ': '셰일가스(Shale Gas)', 'SK가스 ': '셰일가스(Shale Gas)'}, {}, {'한미반도체 ': '반도체 장비', '제우스': '반도체 장비', '제너셈': '반도체 장비', '미래산업 ': '반도체 장비', '오로스테크놀로지': '반도체 장비', '에이팩트': '반도체 장비', '에이피티씨': '반도체 장비', '기가비스': '반도체 장비', '에스티아이': '반도체 장비', '펨트론': '반도체 장비', 'HPSP': '반도체 장비', '엑시콘': '반도체 장비', '이오테크닉스': '반도체 장비', '케이씨텍 ': '반도체 장비', '티에프이': '반도체 장비', 'HB테크놀러지': '반도체 장비', '피에스케이홀딩스': '반도체 장비', '저스템': '반도체 장비', '제이스텍': '반도체 장비', '싸이맥스': '반도체 장비', '인텍플러스': '반도체 장비', '프로텍': '반도체 장비', '에스엔유': '반도체 장비', '주성엔지니어링': '반도체 장비', 'GST': '반도체 장비', '고영': '반도체 장비', '테크윙': '반도체 장비', '레이저쎌': '반도체 장비', '라온테크': '반도체 장비', '위드텍': '반도체 장비', '코세스': '반도체 장비', '더코디': '반도체 장비', '씨앤지하이테크': '반도체 장비', '성우테크론': '반도체 장비', '와이아이케이': '반도체 장비', '한화에어로스페이스 ': '반도체 장비', '코디': '반도체 장비', '에프에스티': '반도체 장비', '디아이 ': '반도체 장비', '한양이엔지': '반도체 장비', '프로이천': '반도체 장비', '유니셈': '반도체 장비', '피에스케이': '반도체 장비', '디바이스이엔지': '반도체 장비', '예스티': '반도체 장비', '러셀': '반도체 장비', '하나마이크론': '반도체 장비', '리노공업': '반도체 장비', '자비스': '반도체 장비', '기가레인': '반도체 장비 ...
# elapsed time = 17.051210165023804
